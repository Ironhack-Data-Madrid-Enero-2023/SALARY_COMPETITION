# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv('salaries_data.csv')

test = pd.read_csv('testeo.csv')

# %%
train.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %%
train.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           500 non-null    int64
#  1   experience_level    500 non-null    object
#  2   employment_type     500 non-null    object
#  3   job_title           500 non-null    object
#  4   salary              500 non-null    int64
#  5   salary_currency     500 non-null    object
#  6   salary_in_usd       500 non-null    int64
#  7   employee_residence  500 non-null    object
#  8   remote_ratio        500 non-null    int64
#  9   company_location    500 non-null    object
#  10  company_size        500 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 224.3 KB

# %%
train.drop(columns = ['salary_currency', 'salary', 'remote_ratio'], inplace=True)

# %%
train.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer         140250
# 1       2022               SE              FT    Data Engineer         135000
# 2       2021               MI              FT  BI Data Analyst         100000
# 3       2021               MI              CT      ML Engineer         270000
# 4       2021               MI              FT    Data Engineer          26005
#
#   employee_residence company_location company_size
# 0                 US               US            M
# 1                 US               US            M
# 2                 US               US            M
# 3                 US               US            L
# 4                 RO               US            L

# %%
train.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# company_location      0
# company_size          0
# dtype: int64

# %%
train.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary_in_usd', 'employee_residence', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
train.salary_in_usd.min(), train.salary_in_usd.mean(), train.salary_in_usd.max()
# Out:
# (2859, 112996.216, 450000)

# %%
train.shape
# Out:
# (500, 8)

# %%
train.experience_level.unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %%
train.company_location.value_counts()[:5]
# Out:
# US    296
# GB     41
# CA     25
# DE     23
# IN     19
# Name: company_location, dtype: int64

# %%
train.pivot_table(index= 'experience_level', columns = 'company_location', values = 'salary_in_usd', aggfunc = 'mean').sort_values(ascending=False, by = 'US')
# Out:
# company_location        AE       AS       AT       AU       BE       BR  \
# experience_level
# EX                     NaN      NaN      NaN      NaN      NaN      NaN
# SE                 92500.0      NaN  91237.0      NaN  82744.0  21453.5
# MI                115000.0      NaN  69489.5  87425.0  88654.0      NaN
# EN                     NaN  18053.0      NaN  86703.0      NaN      NaN
#
# company_location             CA        CH       CL        CN       CZ  \
# experience_level
# EX                157583.000000       NaN      NaN       NaN      NaN
# SE                111523.133333       NaN      NaN       NaN      NaN
# MI                 69754.166667  122346.0  40038.0       NaN  69999.0
# EN                 59698.000000    5882.0      NaN  100000.0      NaN
#
# company_location             DE       DK        DZ       EE            ES  \
# experience_level
# EX                135936.000000      NaN       NaN      NaN  79833.000000
# ...

# %%
exp_level = {'EN' : 1, 'MI' : 2, 'SE': 3, 'EX': 4}

train.experience_level=train.experience_level.apply(lambda x: exp_level[x])

train.head()
# Out:
#    work_year  experience_level employment_type        job_title  \
# 0       2022                 3              FT    Data Engineer
# 1       2022                 3              FT    Data Engineer
# 2       2021                 2              FT  BI Data Analyst
# 3       2021                 2              CT      ML Engineer
# 4       2021                 2              FT    Data Engineer
#
#    salary_in_usd employee_residence company_location company_size
# 0         140250                 US               US            M
# 1         135000                 US               US            M
# 2         100000                 US               US            M
# 3         270000                 US               US            L
# 4          26005                 RO               US            L

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

train.work_year = LabelEncoder().fit_transform(train.work_year)

train.head()
# Out:
#    work_year  experience_level employment_type        job_title  \
# 0          2                 3              FT    Data Engineer
# 1          2                 3              FT    Data Engineer
# 2          1                 2              FT  BI Data Analyst
# 3          1                 2              CT      ML Engineer
# 4          1                 2              FT    Data Engineer
#
#    salary_in_usd employee_residence company_location company_size
# 0         140250                 US               US            M
# 1         135000                 US               US            M
# 2         100000                 US               US            M
# 3         270000                 US               US            L
# 4          26005                 RO               US            L

# %%
train = pd.get_dummies(train, columns=['employment_type', 'company_location'], drop_first=True)

train.head()
# Out:
#    work_year  experience_level        job_title  salary_in_usd  \
# 0          2                 3    Data Engineer         140250
# 1          2                 3    Data Engineer         135000
# 2          1                 2  BI Data Analyst         100000
# 3          1                 2      ML Engineer         270000
# 4          1                 2    Data Engineer          26005
#
#   employee_residence company_size  employment_type_FL  employment_type_FT  \
# 0                 US            M                   0                   1
# 1                 US            M                   0                   1
# 2                 US            M                   0                   1
# 3                 US            L                   0                   0
# 4                 RO            L                   0                   1
#
#    employment_type_PT  company_location_AS  company_location_AT  \
# 0                   0                    0                    0
# ...

# %%
train.drop(columns = ['job_title', 'employee_residence', 'company_size'], inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   work_year            500 non-null    int64
#  1   experience_level     500 non-null    int64
#  2   salary_in_usd        500 non-null    int64
#  3   employment_type_FL   500 non-null    uint8
#  4   employment_type_FT   500 non-null    uint8
#  5   employment_type_PT   500 non-null    uint8
#  6   company_location_AS  500 non-null    uint8
#  7   company_location_AT  500 non-null    uint8
#  8   company_location_AU  500 non-null    uint8
#  9   company_location_BE  500 non-null    uint8
#  10  company_location_BR  500 non-null    uint8
#  11  company_location_CA  500 non-null    uint8
#  12  company_location_CH  500 non-null    uint8
#  13  company_location_CL  500 non-null    uint8
#  14  company_location_CN  500 non-null    uint8
# ...

# %% [markdown]
# ## Test Data EDL

# %%
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   employee_residence  remote_ratio company_location company_size
# 0                 JP             0               JP            S
# 1                 US           100               US            L
# 2                 US           100               US            L
# 3                 CN             0               CN            M
# 4                 IN           100               IN            L

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           107 non-null    int64
#  1   experience_level    107 non-null    object
#  2   employment_type     107 non-null    object
#  3   job_title           107 non-null    object
#  4   employee_residence  107 non-null    object
#  5   remote_ratio        107 non-null    int64
#  6   company_location    107 non-null    object
#  7   company_size        107 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.8+ KB

# %%
test.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
test.drop(columns = 'remote_ratio', inplace=True)

# %%
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#   employee_residence company_location company_size
# 0                 JP               JP            S
# 1                 US               US            L
# 2                 US               US            L
# 3                 CN               CN            M
# 4                 IN               IN            L

# %%
exp_level = {'EN' : 1, 'MI' : 2, 'SE': 3, 'EX': 4}

test.experience_level=test.experience_level.apply(lambda x: exp_level[x])

test.head()
# Out:
#    work_year  experience_level employment_type                   job_title  \
# 0       2020                 3              FT  Machine Learning Scientist
# 1       2020                 2              FT           Lead Data Analyst
# 2       2020                 2              FT                Data Analyst
# 3       2020                 2              FT   Machine Learning Engineer
# 4       2020                 2              FT        Product Data Analyst
#
#   employee_residence company_location company_size
# 0                 JP               JP            S
# 1                 US               US            L
# 2                 US               US            L
# 3                 CN               CN            M
# 4                 IN               IN            L

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

test.work_year = LabelEncoder().fit_transform(test.work_year)

test.head()
# Out:
#    work_year  experience_level employment_type                   job_title  \
# 0          0                 3              FT  Machine Learning Scientist
# 1          0                 2              FT           Lead Data Analyst
# 2          0                 2              FT                Data Analyst
# 3          0                 2              FT   Machine Learning Engineer
# 4          0                 2              FT        Product Data Analyst
#
#   employee_residence company_location company_size
# 0                 JP               JP            S
# 1                 US               US            L
# 2                 US               US            L
# 3                 CN               CN            M
# 4                 IN               IN            L

# %%
test.work_year.value_counts()
# Out:
# 2    55
# 1    36
# 0    16
# Name: work_year, dtype: int64

# %%
test = pd.get_dummies(test, columns=['employment_type', 'company_location'], drop_first=True)

test.head()
# Out:
#    work_year  experience_level                   job_title employee_residence  \
# 0          0                 3  Machine Learning Scientist                 JP
# 1          0                 2           Lead Data Analyst                 US
# 2          0                 2                Data Analyst                 US
# 3          0                 2   Machine Learning Engineer                 CN
# 4          0                 2        Product Data Analyst                 IN
#
#   company_size  employment_type_FT  employment_type_PT  company_location_AU  \
# 0            S                   1                   0                    0
# 1            L                   1                   0                    0
# 2            L                   1                   0                    0
# 3            M                   1                   0                    0
# 4            L                   1                   0                    0
#
# ...

# %%
test.drop(columns = ['job_title', 'employee_residence', 'company_size'], inplace = True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   work_year            107 non-null    int64
#  1   experience_level     107 non-null    int64
#  2   employment_type_FT   107 non-null    uint8
#  3   employment_type_PT   107 non-null    uint8
#  4   company_location_AU  107 non-null    uint8
#  5   company_location_BR  107 non-null    uint8
#  6   company_location_CA  107 non-null    uint8
#  7   company_location_CN  107 non-null    uint8
#  8   company_location_CO  107 non-null    uint8
#  9   company_location_CZ  107 non-null    uint8
#  10  company_location_DE  107 non-null    uint8
#  11  company_location_DK  107 non-null    uint8
#  12  company_location_ES  107 non-null    uint8
#  13  company_location_FR  107 non-null    uint8
#  14  company_location_GB  107 non-null    uint8
# ...

# %%
train.columns
# Out:
# Index(['work_year', 'experience_level', 'salary_in_usd', 'employment_type_FL',
#        'employment_type_FT', 'employment_type_PT', 'company_location_AS',
#        'company_location_AT', 'company_location_AU', 'company_location_BE',
#        'company_location_BR', 'company_location_CA', 'company_location_CH',
#        'company_location_CL', 'company_location_CN', 'company_location_CZ',
#        'company_location_DE', 'company_location_DK', 'company_location_DZ',
#        'company_location_EE', 'company_location_ES', 'company_location_FR',
#        'company_location_GB', 'company_location_GR', 'company_location_HN',
#        'company_location_HU', 'company_location_IE', 'company_location_IN',
#        'company_location_IR', 'company_location_JP', 'company_location_KE',
#        'company_location_LU', 'company_location_MD', 'company_location_MT',
#        'company_location_MX', 'company_location_NG', 'company_location_NL',
# ...

# %%
test.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type_FT',
#        'employment_type_PT', 'company_location_AU', 'company_location_BR',
#        'company_location_CA', 'company_location_CN', 'company_location_CO',
#        'company_location_CZ', 'company_location_DE', 'company_location_DK',
#        'company_location_ES', 'company_location_FR', 'company_location_GB',
#        'company_location_GR', 'company_location_HR', 'company_location_IL',
#        'company_location_IN', 'company_location_IQ', 'company_location_IT',
#        'company_location_JP', 'company_location_MX', 'company_location_MY',
#        'company_location_PL', 'company_location_RU', 'company_location_US'],
#       dtype='object')

# %%
test['employment_type_FL'] = 0
test['company_location_AS'] = 0
test['company_location_AT'] = 0
test['company_location_BE'] = 0
test['company_location_CH'] = 0
test['company_location_CL'] = 0
test['company_location_DZ'] = 0
test['company_location_EE'] = 0
test['company_location_HN'] = 0
test['company_location_HU'] = 0
test['company_location_IE'] = 0
test['company_location_KE'] = 0
test['company_location_LU'] = 0
test['company_location_MD'] = 0
test['company_location_MT'] = 0
test['company_location_NG'] = 0
test['company_location_NL'] = 0
test['company_location_NZ'] = 0
test['company_location_PK'] = 0
test['company_location_PT'] = 0
test['company_location_RO'] = 0
test['company_location_SG'] = 0
test['company_location_SI'] = 0
test['company_location_TR'] = 0
test['company_location_UA'] = 0
test['company_location_VN'] = 0
test['company_location_IR'] = 0

# %%
train['company_location_CO'] = 0
train['company_location_HR'] = 0
train['company_location_IL'] = 0
train['company_location_IQ'] = 0
train['company_location_IT'] = 0
train['company_location_MY'] = 0
train['company_location_RU'] = 0

# %%
test.shape, train.shape
# Out:
# ((107, 54), (500, 55))

# %%
test.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type_FT',
#        'employment_type_PT', 'company_location_AU', 'company_location_BR',
#        'company_location_CA', 'company_location_CN', 'company_location_CO',
#        'company_location_CZ', 'company_location_DE', 'company_location_DK',
#        'company_location_ES', 'company_location_FR', 'company_location_GB',
#        'company_location_GR', 'company_location_HR', 'company_location_IL',
#        'company_location_IN', 'company_location_IQ', 'company_location_IT',
#        'company_location_JP', 'company_location_MX', 'company_location_MY',
#        'company_location_PL', 'company_location_RU', 'company_location_US',
#        'employment_type_FL', 'company_location_AS', 'company_location_AT',
#        'company_location_BE', 'company_location_CH', 'company_location_CL',
#        'company_location_DZ', 'company_location_EE', 'company_location_HN',
#        'company_location_HU', 'company_location_IE', 'company_location_KE',
# ...

# %%
train.columns
# Out:
# Index(['work_year', 'experience_level', 'salary_in_usd', 'employment_type_FL',
#        'employment_type_FT', 'employment_type_PT', 'company_location_AS',
#        'company_location_AT', 'company_location_AU', 'company_location_BE',
#        'company_location_BR', 'company_location_CA', 'company_location_CH',
#        'company_location_CL', 'company_location_CN', 'company_location_CZ',
#        'company_location_DE', 'company_location_DK', 'company_location_DZ',
#        'company_location_EE', 'company_location_ES', 'company_location_FR',
#        'company_location_GB', 'company_location_GR', 'company_location_HN',
#        'company_location_HU', 'company_location_IE', 'company_location_IN',
#        'company_location_IR', 'company_location_JP', 'company_location_KE',
#        'company_location_LU', 'company_location_MD', 'company_location_MT',
#        'company_location_MX', 'company_location_NG', 'company_location_NL',
# ...

# %% [markdown]
# # Modelo

# %%
X = train.drop('salary_in_usd', axis=1)

y = train.salary_in_usd

# %%
from sklearn.model_selection import train_test_split as tts 

X_train, X_test, y_train, y_test = tts(X , y)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((375, 54), (125, 54), (375,), (125,))

# %%
from sklearn.ensemble import RandomForestRegressor as RFR  

rfr = RFR()

rfr.fit(X_train, y_train)

y_pred = rfr.predict(X_test)

y_pred[:5]
# Out:
# array([144646.61155536,  98634.92650794,  28193.12742857, 106735.30666667,
#        144646.61155536])

# %%
from sklearn.metrics import mean_squared_error as mse 

mse(y_test, y_pred, squared=False)
# Out:
# 53898.78080249674

# %%
y_pred_test = rfr.predict(test)

y_pred_test[:5]
# Out:
# /Users/ronaldhernandez/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# array([107834.95421429,  23814.684     ,  23814.684     ,  66827.83      ,
#         46856.9825    ])

# %% [markdown]
# # Muestra

# %%
muestra = pd.read_csv('muestra.csv')

muestra['salary_in_usd'] = y_pred_test

muestra.to_csv('muestra1.csv', index=False)
