# %%
import pandas as pd

# %%
traintrain=pd.read_csv('salaries_data.csv')

# %%
traintrain.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %%
traintrain = traintrain.drop(['salary', 'salary_currency'], axis=1)

# %%
traintrain.head()
# Out:
#    work_year experience_level employment_type        job_title  salary_in_usd  \
# 0       2022               SE              FT    Data Engineer         140250
# 1       2022               SE              FT    Data Engineer         135000
# 2       2021               MI              FT  BI Data Analyst         100000
# 3       2021               MI              CT      ML Engineer         270000
# 4       2021               MI              FT    Data Engineer          26005
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
traintrain.experience_level.value_counts()
# Out:
# SE    243
# MI    172
# EN     65
# EX     20
# Name: experience_level, dtype: int64

# %%
dictio = {'EN':0 , 'MI':1, 'SE':2,'EX':3}

traintrain.experience_level=traintrain.experience_level.apply(lambda x: dictio[x])

# %%
traintrain
# Out:
#      work_year  experience_level employment_type  \
# 0         2022                 2              FT
# 1         2022                 2              FT
# 2         2021                 1              FT
# 3         2021                 1              CT
# 4         2021                 1              FT
# ..         ...               ...             ...
# 495       2022                 2              FT
# 496       2021                 0              FT
# 497       2022                 2              FT
# 498       2021                 1              FT
# 499       2021                 0              FT
#
#                              job_title  salary_in_usd employee_residence  \
# 0                        Data Engineer         140250                 US
# 1                        Data Engineer         135000                 US
# 2                      BI Data Analyst         100000                 US
# 3                          ML Engineer         270000                 US
# ...

# %%
traintrain.employment_type.value_counts()
# Out:
# FT    484
# PT      8
# CT      4
# FL      4
# Name: employment_type, dtype: int64

# %%
dictio = {'FL':0 , 'CT':1, 'PT':2,'FT':3}

traintrain.employment_type=traintrain.employment_type.apply(lambda x: dictio[x])

# %%
traintrain
# Out:
#      work_year  experience_level  employment_type  \
# 0         2022                 2                3
# 1         2022                 2                3
# 2         2021                 1                3
# 3         2021                 1                1
# 4         2021                 1                3
# ..         ...               ...              ...
# 495       2022                 2                3
# 496       2021                 0                3
# 497       2022                 2                3
# 498       2021                 1                3
# 499       2021                 0                3
#
#                              job_title  salary_in_usd employee_residence  \
# 0                        Data Engineer         140250                 US
# 1                        Data Engineer         135000                 US
# 2                      BI Data Analyst         100000                 US
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
traintrain["job_title"] = le.fit_transform(traintrain["job_title"])

# %%
traintrain.employee_residence.unique()
# Out:
# array(['US', 'RO', 'FR', 'GR', 'SI', 'DE', 'IN', 'GB', 'PK', 'MD', 'JP',
#        'CA', 'PT', 'IE', 'AE', 'IT', 'MX', 'VN', 'BE', 'KE', 'ES', 'CH',
#        'CL', 'JE', 'TR', 'NZ', 'UA', 'AU', 'NG', 'BG', 'HK', 'EE', 'CZ',
#        'RU', 'PR', 'AT', 'BR', 'DZ', 'IR', 'NL', 'RS', 'HU', 'PL', 'HN',
#        'MY', 'BO', 'MT', 'LU', 'SG'], dtype=object)

# %%
traintrain["employee_residence"] = le.fit_transform(traintrain["employee_residence"])

# %%
traintrain
# Out:
#      work_year  experience_level  employment_type  job_title  salary_in_usd  \
# 0         2022                 2                3         17         140250
# 1         2022                 2                3         17         135000
# 2         2021                 1                3          5         100000
# 3         2021                 1                1         36         270000
# 4         2021                 1                3         17          26005
# ..         ...               ...              ...        ...            ...
# 495       2022                 2                3         17         100000
# 496       2021                 0                3          7           5882
# 497       2022                 2                3         16          90700
# 498       2021                 1                3         17          82528
# 499       2021                 0                3         11          70000
#
# ...

# %%
traintrain.company_location.value_counts()
# Out:
# US    296
# GB     41
# CA     25
# DE     23
# IN     19
# FR     12
# ES     12
# GR     10
# JP      4
# NL      4
# PT      4
# LU      3
# AE      3
# AT      3
# PL      3
# PK      3
# TR      3
# CH      2
# AU      2
# BR      2
# NG      2
# SI      2
# BE      2
# MT      1
# IR      1
# DZ      1
# HU      1
# CZ      1
# HN      1
# RO      1
# CL      1
# EE      1
# UA      1
# NZ      1
# DK      1
# CN      1
# KE      1
# VN      1
# MX      1
# IE      1
# AS      1
# MD      1
# SG      1
# Name: company_location, dtype: int64

# %%
traintrain["company_location"] = le.fit_transform(traintrain["company_location"])

# %%
traintrain.company_size.value_counts()
# Out:
# M    273
# L    165
# S     62
# Name: company_size, dtype: int64

# %%
dictio = {'S':0 ,'L':1, 'M':2}

traintrain.company_size=traintrain.company_size.apply(lambda x: dictio[x])

# %%
traintrain.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_in_usd  \
# 0       2022                 2                3         17         140250
# 1       2022                 2                3         17         135000
# 2       2021                 1                3          5         100000
# 3       2021                 1                1         36         270000
# 4       2021                 1                3         17          26005
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  47           100                41             2
# 1                  47           100                41             2
# 2                  47           100                41             2
# 3                  47           100                41             1
# 4                  40             0                41             1

# %%
import pylab as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
plt.figure(figsize=(15, 10))      

sns.set(style='white')

mask=np.triu(np.ones_like(traintrain.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(traintrain.corr(),
           mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
X=traintrain[['work_year','experience_level','employment_type','job_title','employee_residence','remote_ratio','company_location','company_size']]
y=traintrain['salary_in_usd']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
traintrain = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split as tts

# %%
X_train, X_test, y_train, y_test  = tts(X, y, train_size=0.8, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 8), (100, 8), (400,), (100,))

# %%
from lazypredict.Supervised import LazyRegressor

# %%
lazy=LazyRegressor()

# %%
lazy.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:02<00:00, 19.85it/s]
# (                               Adjusted R-Squared  R-Squared       RMSE  \
#  Model
#  PassiveAggressiveRegressor                   0.39       0.44   46931.65
#  PoissonRegressor                             0.37       0.42   47625.28
#  HuberRegressor                               0.37       0.42   47727.35
#  LassoLarsIC                                  0.36       0.41   48128.15
#  BayesianRidge                                0.35       0.40   48288.38
#  RidgeCV                                      0.35       0.40   48319.07
#  OrthogonalMatchingPursuitCV                  0.35       0.40   48346.04
#  SGDRegressor                                 0.35       0.40   48354.40
#  Ridge                                        0.35       0.40   48363.76
#  LassoLars                                    0.35       0.40   48364.75
# ...

# %%
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as sq

# %%
model = PoissonRegressor(alpha=1e-12, max_iter=1000, tol=1e-6)
model.fit(X_train, y_train)
# Out:
# PoissonRegressor(alpha=1e-12, max_iter=1000, tol=1e-06)

# %%
import pandas as pd

# %%
testtest=pd.read_csv('testeo.csv')

# %%
len(testtest)
# Out:
# 107

# %%
dictio = {'EN':0 , 'MI':1, 'SE':2,'EX':3}

testtest.experience_level=testtest.experience_level.apply(lambda x: dictio[x])

# %%
dictio = {'FL':0 , 'CT':1, 'PT':2,'FT':3}

testtest.employment_type=testtest.employment_type.apply(lambda x: dictio[x])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
testtest["job_title"] = le.fit_transform(testtest["job_title"])

# %%
testtest["employee_residence"] = le.fit_transform(testtest["employee_residence"])

# %%
testtest["company_location"] = le.fit_transform(testtest["company_location"])

# %%
dictio = {'S':0 ,'L':1, 'M':2}

testtest.company_size=testtest.company_size.apply(lambda x: dictio[x])

# %%
X=testtest[['work_year','experience_level','employment_type','job_title','employee_residence','remote_ratio','company_location','company_size']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
testtest = scaler.fit_transform(X)

# %%
from sklearn.linear_model import PoissonRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
testtest.head()
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0       2020                 2                3         22
# 1       2020                 1                3         18
# 2       2020                 1                3          8
# 3       2020                 1                3         20
# 4       2020                 1                3         27
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  17             0                18             0
# 1                  25           100                23             1
# 2                  25           100                23             1
# 3                   4             0                 4             2
# 4                  14           100                15             1

# %%
traintrain.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_in_usd  \
# 0       2022                 2                3         17         140250
# 1       2022                 2                3         17         135000
# 2       2021                 1                3          5         100000
# 3       2021                 1                1         36         270000
# 4       2021                 1                3         17          26005
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  47           100                41             2
# 1                  47           100                41             2
# 2                  47           100                41             2
# 3                  47           100                41             1
# 4                  40             0                41             1

# %%
X = traintrain.drop('salary_in_usd', axis = 1)
y = traintrain.salary_in_usd

# %%
model = PoissonRegressor(alpha=1e-12, max_iter=1000, tol=1e-6)
model.fit(X, y)
# Out:
# PoissonRegressor(alpha=1e-12, max_iter=1000, tol=1e-06)

# %%
X.head()
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0       2022                 2                3         17
# 1       2022                 2                3         17
# 2       2021                 1                3          5
# 3       2021                 1                1         36
# 4       2021                 1                3         17
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  47           100                41             2
# 1                  47           100                41             2
# 2                  47           100                41             2
# 3                  47           100                41             1
# 4                  40             0                41             1

# %%
traintrain.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_in_usd  \
# 0       2022                 2                3         17         140250
# 1       2022                 2                3         17         135000
# 2       2021                 1                3          5         100000
# 3       2021                 1                1         36         270000
# 4       2021                 1                3         17          26005
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  47           100                41             2
# 1                  47           100                41             2
# 2                  47           100                41             2
# 3                  47           100                41             1
# 4                  40             0                41             1

# %%
y_pred = model.predict(testtest)

# %%
muestra1=pd.read_csv('muestra.csv')

# %%
muestra1['salary_in_usd']= y_pred

# %%
len(y_pred)
# Out:
# 107

# %%
muestra1.to_csv('salary_comp.csv',index=False)
